# %% [markdown]
# <a href="https://colab.research.google.com/github/ask350/Test/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clustering
#
# KMeans

# %%
# %pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /usr/local/lib/python3.10/dist-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (3.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (1.5.2)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)

# %% [markdown]
# # Step 1 - Read the dataset

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/Mall_Customers.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    CustomerID  Gender  Age  Income  Spending
# 0           1    Male   19      15        39
# 1           2    Male   21      15        81
# 2           3  Female   20      16         6
# 3           4  Female   23      16        77
# 4           5  Female   31      17        40

# %% [markdown]
# ## Categorise similat customers based on Income, Spending

# %%
## Step 2- perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  200 non-null    int64
#  1   Gender      200 non-null    object
#  2   Age         200 non-null    int64
#  3   Income      200 non-null    int64
#  4   Spending    200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isna().sum()
# Out:
# CustomerID    0
# Gender        0
# Age           0
# Income        0
# Spending      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step 3 - Seperate X values
# There is no target feature in clustering (Unsupervised Machine Learning)

# %%
X = df[["Income", "Spending"]]
X.head()
# Out:
#    Income  Spending
# 0      15        39
# 1      15        81
# 2      16         6
# 3      16        77
# 4      17        40

# %% [markdown]
# ## Step 4 - Apply preprocessing on X

# %%
X.dtypes
# Out:
# Income      int64
# Spending    int64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
).set_output(transform = "pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#      Income  Spending
# 0 -1.738999 -0.434801
# 1 -1.738999  1.195704
# 2 -1.700830 -1.715913
# 3 -1.700830  1.040418
# 4 -1.662660 -0.395980

# %% [markdown]
# ## Decide number of clusters from yellowbrick package

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
bqse_model = KMeans()
visualizer = KElbowVisualizer(bqse_model, k=(2, 15), timings=False)
visualizer.fit(X_pre)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ## Based on above elbow method we can choose 5 clusters

# %% [markdown]
# ## Build final KMeans model

# %%
best_km = KMeans(n_clusters=5)
best_km.fit(X_pre)
# Out:
# KMeans(n_clusters=5)

# %%
X2 = X.copy()

# %%
X2
# Out:
#      Income  Spending
# 0        15        39
# 1        15        81
# 2        16         6
# 3        16        77
# 4        17        40
# ..      ...       ...
# 195     120        79
# 196     126        28
# 197     126        74
# 198     137        18
# 199     137        83
#
# [200 rows x 2 columns]

# %%
X2["Label"] = best_km.labels_
X2.head()
# Out:
#    Income  Spending  Lable  Label
# 0      15        39      0      0
# 1      15        81      4      4
# 2      16         6      0      0
# 3      16        77      4      4
# 4      17        40      0      0

# %% [markdown]
# ### in labels 0 to 4 clusters will be there

# %%
X2.query("Label == 0")
# Out:
#      Income  Spending  Lable  Label
# 0        15        39      0      0
# 2        16         6      0      0
# 4        17        40      0      0
# 6        18         6      0      0
# 8        19         3      0      0
# ..      ...       ...    ...    ...
# 118      67        43      0      0
# 119      67        57      0      0
# 120      67        56      0      0
# 121      67        40      0      0
# 122      69        58      0      0
#
# [101 rows x 4 columns]

# %%
for i in range(5):
  print(f"cluster Number : {i}")
  c = X2.query(f"Label == {i}")
  display(c)
  print("\n======================================================\n")
# Out:
# cluster Number : 0
#      Income  Spending  Lable  Label
# 0        15        39      0      0
# 2        16         6      0      0
# 4        17        40      0      0
# 6        18         6      0      0
# 8        19         3      0      0
# ..      ...       ...    ...    ...
# 118      67        43      0      0
# 119      67        57      0      0
# 120      67        56      0      0
# 121      67        40      0      0
# 122      69        58      0      0
#
# [101 rows x 4 columns]
# ======================================================
#
# cluster Number : 1
#      Income  Spending  Lable  Label
# 123      69        91      1      1
# 125      70        77      1      1
# 127      71        95      1      1
# 129      71        75      1      1
# 131      71        75      1      1
# 133      72        71      1      1
# 135      73        88      1      1
# 137      73        73      1      1
# 139      74        72      1      1
# 141      75        93      1      1
# 143      76        87      1      1
# 145      77        97      1      1
# 147      77        74      1      1
# 149      78        90      1      1
# 151      78        88      1      1
# 153      78        76      1      1
# 155      78        89      1      1
# 157      78        78      1      1
# 159      78        73      1      1
# 161      79        83      1      1
# 163      81        93      1      1
# 165      85        75      1      1
# 167      86        95      1      1
# 169      87        63      1      1
# 171      87        75      1      1
# 173      87        92      1      1
# 175      88        86      1      1
# 177      88        69      1      1
# 179      93        90      1      1
# 181      97        86      1      1
# 183      98        88      1      1
# 185      99        97      1      1
# 187     101        68      1      1
# 189     103        85      1      1
# 191     103        69      1      1
# 193     113        91      1      1
# 195     120        79      1      1
# 197     126        74      1      1
# 199     137        83      1      1
# ======================================================
#
# cluster Number : 2
#      Income  Spending  Lable  Label
# 180      97        32      2      2
# 182      98        15      2      2
# 184      99        39      2      2
# 186     101        24      2      2
# 188     103        17      2      2
# 190     103        23      2      2
# 192     113         8      2      2
# 194     120        16      2      2
# 196     126        28      2      2
# 198     137        18      2      2
# ======================================================
#
# cluster Number : 3
#      Income  Spending  Lable  Label
# 124      70        29      3      3
# 126      71        35      3      3
# 128      71        11      3      3
# 130      71         9      3      3
# 132      72        34      3      3
# 134      73         5      3      3
# 136      73         7      3      3
# 138      74        10      3      3
# 140      75         5      3      3
# 142      76        40      3      3
# 144      77        12      3      3
# 146      77        36      3      3
# 148      78        22      3      3
# 150      78        17      3      3
# 152      78        20      3      3
# 154      78        16      3      3
# 156      78         1      3      3
# 158      78         1      3      3
# 160      79        35      3      3
# 162      81         5      3      3
# 164      85        26      3      3
# 166      86        20      3      3
# 168      87        27      3      3
# 170      87        13      3      3
# 172      87        10      3      3
# 174      88        13      3      3
# 176      88        15      3      3
# 178      93        14      3      3
# ======================================================
#
# cluster Number : 4
#     Income  Spending  Lable  Label
# 1       15        81      4      4
# 3       16        77      4      4
# 5       17        76      4      4
# 7       18        94      4      4
# 9       19        72      4      4
# 11      19        99      4      4
# 13      20        77      4      4
# 15      20        79      4      4
# 17      21        66      4      4
# 19      23        98      4      4
# 21      24        73      4      4
# 23      25        73      4      4
# 25      28        82      4      4
# 27      28        61      4      4
# 29      29        87      4      4
# 31      30        73      4      4
# 33      33        92      4      4
# 35      33        81      4      4
# 37      34        73      4      4
# 39      37        75      4      4
# 41      38        92      4      4
# 45      39        65      4      4
# ======================================================

# %%
X2.to_csv("KMeansResults.csv", index=False)

# %% [markdown]
# ## Visualising the clusters

# %%
import seaborn as sns
sns.scatterplot(data=X2, x="Income", y="Spending", hue="Label", palette="husl")
# Out:
# <Axes: xlabel='Income', ylabel='Spending'>

# %% [markdown]
# ## 2. Agglomerative Clustering (Bottom-Up approach)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model_agc = AgglomerativeClustering()
visualizer2 = KElbowVisualizer(model_agc, k=(2, 15), timings=False)
visualizer2.fit(X_pre)
visualizer2.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Lower the distortion score better the model

# %% [markdown]
# ## Based on above i can use n_clusters=5

# %%
X_pre.head()
# Out:
#      Income  Spending
# 0 -1.738999 -0.434801
# 1 -1.738999  1.195704
# 2 -1.700830 -1.715913
# 3 -1.700830  1.040418
# 4 -1.662660 -0.395980

# %%
best_agc = AgglomerativeClustering(n_clusters=5)
best_agc.fit(X_pre)
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
X3 = X.copy()
X3.head()
# Out:
#    Income  Spending
# 0      15        39
# 1      15        81
# 2      16         6
# 3      16        77
# 4      17        40

# %%
X3["Label"] = best_agc.labels_
X3.head()
# Out:
#    Income  Spending  Label
# 0      15        39      4
# 1      15        81      3
# 2      16         6      4
# 3      16        77      3
# 4      17        40      4

# %%
for i in range(5):
  print(f"cluster Number : {i}")
  c = X3.query(f"Label == {i}")
  display(c)
  print("\n======================================================\n")
# Out:
# cluster Number : 0
#      Income  Spending  Label
# 128      71        11      0
# 130      71         9      0
# 134      73         5      0
# 136      73         7      0
# 138      74        10      0
# 140      75         5      0
# 144      77        12      0
# 148      78        22      0
# 150      78        17      0
# 152      78        20      0
# 154      78        16      0
# 156      78         1      0
# 158      78         1      0
# 162      81         5      0
# 164      85        26      0
# 166      86        20      0
# 168      87        27      0
# 170      87        13      0
# 172      87        10      0
# 174      88        13      0
# 176      88        15      0
# 178      93        14      0
# 180      97        32      0
# 182      98        15      0
# 184      99        39      0
# 186     101        24      0
# 188     103        17      0
# 190     103        23      0
# 192     113         8      0
# 194     120        16      0
# 196     126        28      0
# 198     137        18      0
# ======================================================
#
# cluster Number : 1
#      Income  Spending  Label
# 123      69        91      1
# 125      70        77      1
# 127      71        95      1
# 129      71        75      1
# 131      71        75      1
# 133      72        71      1
# 135      73        88      1
# 137      73        73      1
# 139      74        72      1
# 141      75        93      1
# 143      76        87      1
# 145      77        97      1
# 147      77        74      1
# 149      78        90      1
# 151      78        88      1
# 153      78        76      1
# 155      78        89      1
# 157      78        78      1
# 159      78        73      1
# 161      79        83      1
# 163      81        93      1
# 165      85        75      1
# 167      86        95      1
# 169      87        63      1
# 171      87        75      1
# 173      87        92      1
# 175      88        86      1
# 177      88        69      1
# 179      93        90      1
# 181      97        86      1
# 183      98        88      1
# 185      99        97      1
# 187     101        68      1
# 189     103        85      1
# 191     103        69      1
# 193     113        91      1
# 195     120        79      1
# 197     126        74      1
# 199     137        83      1
# ======================================================
#
# cluster Number : 2
#      Income  Spending  Label
# 43       39        61      2
# 45       39        65      2
# 46       40        55      2
# 47       40        47      2
# 48       40        42      2
# ..      ...       ...    ...
# 126      71        35      2
# 132      72        34      2
# 142      76        40      2
# 146      77        36      2
# 160      79        35      2
#
# [85 rows x 3 columns]
# ======================================================
#
# cluster Number : 3
#     Income  Spending  Label
# 1       15        81      3
# 3       16        77      3
# 5       17        76      3
# 7       18        94      3
# 9       19        72      3
# 11      19        99      3
# 13      20        77      3
# 15      20        79      3
# 17      21        66      3
# 19      23        98      3
# 21      24        73      3
# 23      25        73      3
# 25      28        82      3
# 27      28        61      3
# 29      29        87      3
# 31      30        73      3
# 33      33        92      3
# 35      33        81      3
# 37      34        73      3
# 39      37        75      3
# 41      38        92      3
# ======================================================
#
# cluster Number : 4
#     Income  Spending  Label
# 0       15        39      4
# 2       16         6      4
# 4       17        40      4
# 6       18         6      4
# 8       19         3      4
# 10      19        14      4
# 12      20        15      4
# 14      20        13      4
# 16      21        35      4
# 18      23        29      4
# 20      24        35      4
# 22      25         5      4
# 24      28        14      4
# 26      28        32      4
# 28      29        31      4
# 30      30         4      4
# 32      33         4      4
# 34      33        14      4
# 36      34        17      4
# 38      37        26      4
# 40      38        35      4
# 42      39        36      4
# 44      39        28      4
# ======================================================

# %%
X3.to_csv("AGCResults.csv", index=False)

# %%
sns.scatterplot(data=X3, x="Income", y="Spending", hue="Label", palette="husl")
# Out:
# <Axes: xlabel='Income', ylabel='Spending'>
